# %%
import pandas as pd

df = pd.read_excel('base_transportes.xlsx')
df
# Out:
#                    Gás Meio de Transporte          Combustivel  \
# 0              CH4 (t)        Ferroviário            Biodiesel
# 1              CH4 (t)        Ferroviário            Biodiesel
# 2              CH4 (t)        Ferroviário            Biodiesel
# 3              CH4 (t)        Ferroviário            Biodiesel
# 4     CO2e (t) GWP-AR6        Ferroviário            Biodiesel
# ...                ...                ...                  ...
# 8362         COVNM (t)         Rodoviário  Gasolina automotiva
# 8363           N2O (t)         Rodoviário  Gasolina automotiva
# 8364           N2O (t)         Rodoviário  Gasolina automotiva
# 8365           NOx (t)         Rodoviário  Gasolina automotiva
# 8366           NOx (t)         Rodoviário  Gasolina automotiva
#
#      Tipo de Transporte                  Atividade              Estado  2000  \
# 0           Locomotivas        Transporte de carga               Amapá   0.0
# ...

# %%
# dict = {
#     'Ano': [],
#     'Gás Total': [] 
# }


# for ano in [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]:
#     ano_valor, gas_total = pd.melt(df, value_vars=[ano])
#     list_ano_valor = list(ano_valor)
#     list_gas_total = list(gas_total)

#     dict['Ano'].append(ano_valor[1])
#     dict['Gás Total'].append(gas_total[1])

# %%
df = df[df['Gás'] == 'CO2e (t) GWP-AR6']
df
# Out:
#                    Gás Meio de Transporte          Combustivel  \
# 4     CO2e (t) GWP-AR6        Ferroviário            Biodiesel
# 5     CO2e (t) GWP-AR6        Ferroviário            Biodiesel
# 6     CO2e (t) GWP-AR6        Ferroviário            Biodiesel
# 7     CO2e (t) GWP-AR6        Ferroviário            Biodiesel
# 29    CO2e (t) GWP-AR6        Ferroviário            Biodiesel
# ...                ...                ...                  ...
# 8249  CO2e (t) GWP-AR6         Rodoviário  Gasolina automotiva
# 8250  CO2e (t) GWP-AR6         Rodoviário  Gasolina automotiva
# 8347  CO2e (t) GWP-AR6         Rodoviário  Gasolina automotiva
# 8355  CO2e (t) GWP-AR6         Rodoviário  Gasolina automotiva
# 8356  CO2e (t) GWP-AR6         Rodoviário  Gasolina automotiva
#
#      Tipo de Transporte                  Atividade              Estado  \
# 4           Locomotivas        Transporte de carga               Amapá
# ...

# %%
df[['ano', 'valor']] = pd.melt(df, id_vars=['Gás', 'Meio de Transporte', 'Combustivel', 'Tipo de Transporte', 'Atividade', 'Estado'], value_vars=[2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df[['ano', 'valor']] = pd.melt(df, id_vars=['Gás', 'Meio de Transporte', 'Combustivel', 'Tipo de Transporte', 'Atividade', 'Estado'], value_vars=[2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])
#       2 df
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# ...
